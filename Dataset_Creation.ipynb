# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import os

# %%
# !ffmpeg -i "/content/drive/MyDrive/deeplearning/vid1.mp4" -vf fps=30 "/content/drive/MyDrive/deeplearning/vid1/a%d.png"
# Out:
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %%
image_1 = cv2.imread("/content/drive/MyDrive/deeplearning/vid1/a100.png")

print(image_1.shape)

cv2_imshow(image_1)
# Out:
# (1080, 1920, 3)
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x7FF2B24F9F10>

# %%
image = cv2.imread("/content/drive/MyDrive/deeplearning/vid1/{}.png".format('a100'))
image_crp = image[:,650:1450]
cv2_imshow(image_crp)
# Out:
# <PIL.Image.Image image mode=RGB size=800x1080 at 0x7FF2B0CCE9D0>

# %%
frame_dir = r"/content/drive/MyDrive/deeplearning/vid1"
output_dir = "/content/drive/MyDrive/deeplearning/vid1"
for i in  (os.listdir(frame_dir)):
  print(i)
  image = cv2.imread("/content/drive/MyDrive/deeplearning/vid1/{}".format(i))
  image_crp = image[:,650:1450]
  image_resize = cv2.resize(image_crp,(256,256))
  cv2.imwrite('/content/drive/MyDrive/deeplearning/vid1/{}'.format(i),image_resize)
# Out:
# a1.png
# a2.png
# a3.png
# a4.png
# a5.png
# a6.png
# a7.png
# a8.png
# a9.png
# a10.png
# a11.png
# a12.png
# a13.png
# a14.png
# a15.png
# a16.png
# a17.png
# a18.png
# a19.png
# a20.png
# a21.png
# a22.png
# a23.png
# a24.png
# a25.png
# a26.png
# a27.png
# a28.png
# a29.png
# a30.png
# a31.png
# a32.png
# a33.png
# a34.png
# a35.png
# a36.png
# a37.png
# a38.png
# a39.png
# a40.png
# a41.png
# a42.png
# a43.png
# a44.png
# a45.png
# a46.png
# a47.png
# a48.png
# a49.png
# a50.png
# a51.png
# a52.png
# a53.png
# a54.png
# a55.png
# a56.png
# a57.png
# a58.png
# a59.png
# a60.png
# a61.png
# a62.png
# a63.png
# a64.png
# a65.png
# a66.png
# a67.png
# a68.png
# a69.png
# a70.png
# a71.png
# a72.png
# a73.png
# a74.png
# a75.png
# a76.png
# a77.png
# a78.png
# a79.png
# a80.png
# a81.png
# a82.png
# a83.png
# a84.png
# a85.png
# a86.png
# a87.png
# a88.png
# a89.png
# a90.png
# a91.png
# a92.png
# a93.png
# a94.png
# a95.png
# a96.png
# a97.png
# a98.png
# a99.png
# a100.png
# ...

# %%
for i in (os.listdir(frame_dir)):
  print(i)
  image = cv2.imread("/content/drive/MyDrive/deeplearning/vid1/{}".format(i))
  img_bw = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  cv2.imwrite('/content/drive/MyDrive/deeplearning/vid1/{}'.format(i),img_bw)
# Out:
# a1.png
# a2.png
# a3.png
# a4.png
# a5.png
# a6.png
# a7.png
# a8.png
# a9.png
# a10.png
# a11.png
# a12.png
# a13.png
# a14.png
# a15.png
# a16.png
# a17.png
# a18.png
# a19.png
# a20.png
# a21.png
# a22.png
# a23.png
# a24.png
# a25.png
# a26.png
# a27.png
# a28.png
# a29.png
# a30.png
# a31.png
# a32.png
# a33.png
# a34.png
# a35.png
# a36.png
# a37.png
# a38.png
# a39.png
# a40.png
# a41.png
# a42.png
# a43.png
# a44.png
# a45.png
# a46.png
# a47.png
# a48.png
# a49.png
# a50.png
# a51.png
# a52.png
# a53.png
# a54.png
# a55.png
# a56.png
# a57.png
# a58.png
# a59.png
# a60.png
# a61.png
# a62.png
# a63.png
# a64.png
# a65.png
# a66.png
# a67.png
# a68.png
# a69.png
# a70.png
# a71.png
# a72.png
# a73.png
# a74.png
# a75.png
# a76.png
# a77.png
# a78.png
# a79.png
# a80.png
# a81.png
# a82.png
# a83.png
# a84.png
# a85.png
# a86.png
# a87.png
# a88.png
# a89.png
# a90.png
# a91.png
# a92.png
# a93.png
# a94.png
# a95.png
# a96.png
# a97.png
# a98.png
# a99.png
# a100.png
# ...

# %%
image_1 = cv2.imread("/content/drive/MyDrive/deeplearning/vid1/a100.png")
image_2 = cv2.imread("/content/drive/MyDrive/deeplearning/vid1/{}.png".format("a101"))

image_1_b_w = cv2.cvtColor(image_1, cv2.COLOR_BGR2GRAY )
image_2_b_w = cv2.cvtColor(image_2, cv2.COLOR_BGR2GRAY )

absdiff = cv2.absdiff(image_1_b_w,image_2_b_w)

cv2_imshow(absdiff)
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7FF2B0C81610>

# %%
frame_dir = r"/content/drive/MyDrive/deeplearning/vid1"
print(len(os.listdir(frame_dir)))
for i in range(1,len(os.listdir(frame_dir))):
  print(i)
  print(i+1)  
  print("----------")
  

  image_1 = cv2.imread(r"/content/drive/MyDrive/deeplearning/vid1/a{}.png".format(i))
  image_2 = cv2.imread(r"/content/drive/MyDrive/deeplearning/vid1/a{}.png".format(i+1))

  image_1_b_w = cv2.cvtColor(image_1, cv2.COLOR_BGR2GRAY )
  image_2_b_w = cv2.cvtColor(image_2, cv2.COLOR_BGR2GRAY )

  absdiff = cv2.absdiff(image_1_b_w,image_2_b_w)
  cv2.imwrite(r'/content/drive/MyDrive/deeplearning/vid1/a{}.png'.format(i),absdiff)

  #cv2_imshow(absdiff)"""
# Out:
# Streaming output truncated to the last 5000 lines.
# 553
# ----------
# 553
# 554
# ----------
# 554
# 555
# ----------
# 555
# 556
# ----------
# 556
# 557
# ----------
# 557
# 558
# ----------
# 558
# 559
# ----------
# 559
# 560
# ----------
# 560
# 561
# ----------
# 561
# 562
# ----------
# 562
# 563
# ----------
# 563
# 564
# ----------
# 564
# 565
# ----------
# 565
# 566
# ----------
# 566
# 567
# ----------
# 567
# 568
# ----------
# 568
# 569
# ----------
# 569
# 570
# ----------
# 570
# 571
# ----------
# 571
# 572
# ----------
# 572
# 573
# ----------
# 573
# 574
# ----------
# 574
# 575
# ----------
# 575
# 576
# ----------
# 576
# 577
# ----------
# 577
# 578
# ----------
# 578
# 579
# ----------
# 579
# 580
# ----------
# 580
# 581
# ----------
# 581
# 582
# ----------
# 582
# 583
# ----------
# 583
# 584
# ----------
# 584
# 585
# ----------
# 585
# 586
# ----------
# 586
# 587
# ----------
# 587
# 588
# ----------
# 588
# 589
# ----------
# 589
# 590
# ----------
# ...

# %%
for i in range(1,len(os.listdir(frame_dir)),30):
  
  print(i)
  print(len(os.listdir(frame_dir))+1)
# Out:
# 1
# 2220
# 31
# 2220
# 61
# 2220
# 91
# 2220
# 121
# 2220
# 151
# 2220
# 181
# 2220
# 211
# 2220
# 241
# 2220
# 271
# 2220
# 301
# 2220
# 331
# 2220
# 361
# 2220
# 391
# 2220
# 421
# 2220
# 451
# 2220
# 481
# 2220
# 511
# 2220
# 541
# 2220
# 571
# 2220
# 601
# 2220
# 631
# 2220
# 661
# 2220
# 691
# 2220
# 721
# 2220
# 751
# 2220
# 781
# 2220
# 811
# 2220
# 841
# 2220
# 871
# 2220
# 901
# 2220
# 931
# 2220
# 961
# 2220
# 991
# 2220
# 1021
# 2220
# 1051
# 2220
# 1081
# 2220
# 1111
# 2220
# 1141
# 2220
# 1171
# 2220
# 1201
# 2220
# 1231
# 2220
# 1261
# 2220
# 1291
# 2220
# 1321
# 2220
# 1351
# 2220
# 1381
# 2220
# 1411
# 2220
# 1441
# 2220
# 1471
# 2220
# 1501
# 2220
# 1531
# 2220
# 1561
# 2220
# 1591
# 2220
# 1621
# 2220
# 1651
# 2220
# 1681
# 2220
# 1711
# 2220
# 1741
# 2220
# 1771
# 2220
# 1801
# 2220
# 1831
# 2220
# 1861
# 2220
# 1891
# 2220
# 1921
# 2220
# 1951
# 2220
# 1981
# 2220
# 2011
# 2220
# 2041
# 2220
# 2071
# 2220
# 2101
# 2220
# 2131
# 2220
# 2161
# 2220
# 2191
# 2220

# %%
def rotate_image(image, angle):
  image_center = tuple(np.array(image.shape[1::-1]) / 2)
  rot_mat = cv2.getRotationMatrix2D(image_center, angle, 1.0)
  result = cv2.warpAffine(image, rot_mat, image.shape[1::-1], flags=cv2.INTER_LINEAR)
  return result
print(image_1.shape)
# Out:
# (256, 256, 3)

# %%
frame_dir = r"/content/drive/MyDrive/deeplearning/vid1"
import random

print(random.randint(0,9))
for i in range(1,len(os.listdir(frame_dir)),20):
  print(i)
  img = cv2.imread("/content/drive/MyDrive/deeplearning/vid1/a{}.png".format(i))
  image_rot = rotate_image(img,(random.randint(-25,25)))
  print("ran",random.randint(-25,25))
  cv2.imwrite(r'/content/drive/MyDrive/deeplearning/vid1/a{}.png'.format(len(os.listdir(frame_dir))+1),image_rot)
# Out:
# 7
# 1
# ran 1
# 21
# ran -21
# 41
# ran -13
# 61
# ran 15
# 81
# ran 22
# 101
# ran -19
# 121
# ran -21
# 141
# ran 9
# 161
# ran -7
# 181
# ran -3
# 201
# ran 19
# 221
# ran 18
# 241
# ran 23
# 261
# ran -17
# 281
# ran 19
# 301
# ran 15
# 321
# ran -23
# 341
# ran -23
# 361
# ran 19
# 381
# ran 5
# 401
# ran 23
# 421
# ran -14
# 441
# ran 3
# 461
# ran -8
# 481
# ran -16
# 501
# ran 22
# 521
# ran -10
# 541
# ran -24
# 561
# ran -22
# 581
# ran 16
# 601
# ran -25
# 621
# ran -14
# 641
# ran -15
# 661
# ran 12
# 681
# ran -3
# 701
# ran 22
# 721
# ran -24
# 741
# ran 16
# 761
# ran -13
# 781
# ran -13
# 801
# ran 24
# 821
# ran 23
# 841
# ran -3
# 861
# ran -20
# 881
# ran -21
# 901
# ran -24
# 921
# ran -17
# 941
# ran -12
# 961
# ran 11
# 981
# ran 24
# 1001
# ran -24
# 1021
# ran 23
# 1041
# ran -14
# 1061
# ran 16
# 1081
# ran 25
# 1101
# ran -6
# 1121
# ran -13
# 1141
# ran -22
# 1161
# ran 13
# 1181
# ran -15
# 1201
# ran 8
# 1221
# ran 0
# 1241
# ran -11
# 1261
# ran -6
# ...
